# %% [markdown]
# <a href="https://colab.research.google.com/github/eflores5000/08MIAR_APR/blob/main/proyecto_final_APR_V06_5_en_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ## 1.3. Montar carpeta de datos local (solo Colab)

# %%
drive.flush_and_unmount()
#drive.mount('/content/drive')
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# Archivos en el directorio:
# ['dqn_models', 'checkpoints', 'dqn_05_weights.h5f.data-00000-of-00001', 'dqn_05_weights.h5f.index', 'dqn_06_weights.h5f.index', 'dqn_06_weights.h5f.data-00000-of-00001', 'dqn_07_weights.h5f.index', 'dqn_07_weights.h5f.data-00000-of-00001', 'dqn_08_weights.h5f.data-00000-of-00001', 'dqn_08_weights.h5f.index', '.ipynb_checkpoints', 'dqn_09_weights.h5f.index', 'dqn_09_weights.h5f.data-00000-of-00001', 'dqn_06_1_weights.h5f.data-00000-of-00001', 'dqn_06_1_weights.h5f.index', 'video', 'dqn_06_3_weights.h5f.index', 'dqn_06_3_weights.h5f.data-00000-of-00001', 'dqn_06_4_weights.h5f.index', 'dqn_06_4_weights.h5f.data-00000-of-00001', 'dqn_v0_weights.h5f.index', 'dqn_v0_weights.h5f.data-00000-of-00001', 'dqn_v06_4_weights.h5f.data-00000-of-00001', 'dqn_v06_4_weights.h5f.index', 'dqn_v06_5_weights.h5f.data-00000-of-00001', 'dqn_v06_5_weights.h5f.index', 'dqn_v06_5_1_weights.h5f.data-00000-of-00001', 'dqn_v06_5_1_weights.h5f.index', 'dqn_v06_x_weights.h5f.index', 'dqn_v06_x_weights.h5f.data-00000-of-00001', 'dqn_v06_x2_weights.h5f.data-00000-of-00001', 'dqn_v06_x2_weights.h5f.index', 'checkpoint']

# %% [markdown]
# ## 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12  #2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.05
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.1.0
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-q98zpsxk
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-q98zpsxk
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.2.2)
# Requirement already satisfied: tensorflow==2.12 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.2.2)

# %% [markdown]
# ## **PARTE 3**. Desarrollo y preguntas
# Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Permute
#from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

height, width, channels = env.observation_space.shape
obs = env.reset()
print(height, width, channels)
print("Forma de la observación:", obs.shape)  # Debe ser (height, width, channels)
env.unwrapped.get_action_meanings()
# Out:
# 210 160 3
# Forma de la observación: (210, 160, 3)
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# ## 1. EJFM Implementación de la red neuronal

# %%
def build_model(height, width, channels, actions):

    model = Sequential()
    model.add(Permute((2, 3, 1), input_shape=(4, 84, 84)))  # WINDOW_LENGTH, H, W
    model.add(Conv2D(32, (8, 8), strides=(4, 4), activation='relu')) #, input_shape=(4, 84, 84), data_format='channels_first')) #input_shape=(4,84,84,1)))
    model.add(Conv2D(64, (4, 4), strides=(2, 2), activation='relu'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), activation='relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %%
model = build_model(84, 84, 1, nb_actions)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. EJFM Implementación de la solución DQN

# %%
from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy

# %%
def build_agent(model, actions):
    policy = LinearAnnealedPolicy(
        EpsGreedyQPolicy(),
        attr='eps',
        value_max=1.0,
        value_min=0.1,
        value_test=0.05,
        nb_steps=1000000)

    memory = SequentialMemory(
        limit=1000000,                       # Replay Buffer (Memoria de experiencias pasadas (s,a,r,s'))
        window_length=4)

    dqn = DQNAgent(model=model,
                   nb_actions=nb_actions,
                   policy=policy,
                   memory=memory,
                   processor=AtariProcessor(),
                   nb_steps_warmup=50000,
                   gamma=0.99,
                   target_model_update=10000, # cada 10,000 steps actualiza la red objetivo
                   train_interval=10,         # Solo entrena cada n pasos de interacción con el entorno
                   delta_clip=1.0,            # Valor utilizado para recortar los errores TD (diferencia temporal) durante el entrenamiento para evitar fluctuaciones externas
                   enable_double_dqn=True,
                   enable_dueling_network=True,
                   dueling_type='avg',
                   batch_size=32,
                   )
    return dqn

# %%
from rl.callbacks import ModelIntervalCheckpoint

# Guardar el modelo cada 25,000 pasos
checkpoint_callback = ModelIntervalCheckpoint(
    filepath='checkpoints/dqn_v10_weights_{step}.h5f',
    interval=25000,
    verbose=1
)

# %%
import os
os.makedirs("checkpoints", exist_ok=True)

# %%
from keras.optimizers import Adam

dqn = build_agent(model, nb_actions)
dqn.compile(Adam(learning_rate=0.00025, epsilon=0.001))

# %%
from datetime import datetime

print(f"⏱ Tiempo de inicio: {datetime.now().strftime('%H:%M:%S')}")

dqn.fit(env, nb_steps=750000, visualize=False, verbose=2,callbacks=[checkpoint_callback])

print(f"⏱ Tiempo de fin: {datetime.now().strftime('%H:%M:%S')}")

# Guardando modelo
dqn.save_weights('dqn_v10_weights.h5f')
# Out:
# ⏱ Tiempo de inicio: 14:25:00
# Training for 750000 steps ...
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#     625/750000: episode: 1, duration: 2.517s, episode steps: 625, steps per second: 248, episode reward: 11.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.494 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    1269/750000: episode: 2, duration: 2.472s, episode steps: 644, steps per second: 260, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.394 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    1924/750000: episode: 3, duration: 2.524s, episode steps: 655, steps per second: 259, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.417 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    2333/750000: episode: 4, duration: 2.209s, episode steps: 409, steps per second: 185, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.357 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3018/750000: episode: 5, duration: 3.216s, episode steps: 685, steps per second: 213, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.502 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3407/750000: episode: 6, duration: 1.490s, episode steps: 389, steps per second: 261, episode reward:  8.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.460 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    3752/750000: episode: 7, duration: 1.340s, episode steps: 345, steps per second: 257, episode reward:  5.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.383 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    4699/750000: episode: 8, duration: 3.767s, episode steps: 947, steps per second: 251, episode reward: 11.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.507 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    5093/750000: episode: 9, duration: 1.606s, episode steps: 394, steps per second: 245, episode reward:  3.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.462 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    5486/750000: episode: 10, duration: 2.402s, episode steps: 393, steps per second: 164, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.450 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    5957/750000: episode: 11, duration: 2.151s, episode steps: 471, steps per second: 219, episode reward:  3.000, mean reward:  0.006 [ 0.000,  1.000], mean action: 2.448 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    6663/750000: episode: 12, duration: 2.704s, episode steps: 706, steps per second: 261, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.455 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    7385/750000: episode: 13, duration: 2.772s, episode steps: 722, steps per second: 260, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.424 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    8191/750000: episode: 14, duration: 3.095s, episode steps: 806, steps per second: 260, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.478 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9046/750000: episode: 15, duration: 4.494s, episode steps: 855, steps per second: 190, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.575 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9553/750000: episode: 16, duration: 1.965s, episode steps: 507, steps per second: 258, episode reward:  2.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#    9960/750000: episode: 17, duration: 1.567s, episode steps: 407, steps per second: 260, episode reward: 10.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 2.459 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   10524/750000: episode: 18, duration: 2.189s, episode steps: 564, steps per second: 258, episode reward:  4.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.438 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   11085/750000: episode: 19, duration: 2.185s, episode steps: 561, steps per second: 257, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.403 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   11663/750000: episode: 20, duration: 3.014s, episode steps: 578, steps per second: 192, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.367 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   12329/750000: episode: 21, duration: 2.960s, episode steps: 666, steps per second: 225, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   13003/750000: episode: 22, duration: 2.593s, episode steps: 674, steps per second: 260, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.536 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   13654/750000: episode: 23, duration: 2.516s, episode steps: 651, steps per second: 259, episode reward:  7.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.567 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   14415/750000: episode: 24, duration: 2.946s, episode steps: 761, steps per second: 258, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.527 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   15233/750000: episode: 25, duration: 4.372s, episode steps: 818, steps per second: 187, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   15951/750000: episode: 26, duration: 2.758s, episode steps: 718, steps per second: 260, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.483 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   16623/750000: episode: 27, duration: 2.585s, episode steps: 672, steps per second: 260, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.463 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   17414/750000: episode: 28, duration: 3.047s, episode steps: 791, steps per second: 260, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.549 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   18218/750000: episode: 29, duration: 4.326s, episode steps: 804, steps per second: 186, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.525 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   18838/750000: episode: 30, duration: 2.404s, episode steps: 620, steps per second: 258, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.440 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   19475/750000: episode: 31, duration: 2.438s, episode steps: 637, steps per second: 261, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.414 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   19843/750000: episode: 32, duration: 1.404s, episode steps: 368, steps per second: 262, episode reward:  3.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.351 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   20640/750000: episode: 33, duration: 3.049s, episode steps: 797, steps per second: 261, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.511 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   21204/750000: episode: 34, duration: 3.406s, episode steps: 564, steps per second: 166, episode reward:  3.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 2.372 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   22010/750000: episode: 35, duration: 3.113s, episode steps: 806, steps per second: 259, episode reward: 13.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   22702/750000: episode: 36, duration: 2.659s, episode steps: 692, steps per second: 260, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.376 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   23264/750000: episode: 37, duration: 2.143s, episode steps: 562, steps per second: 262, episode reward:  3.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 2.480 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   23741/750000: episode: 38, duration: 1.824s, episode steps: 477, steps per second: 262, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.346 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   24213/750000: episode: 39, duration: 3.022s, episode steps: 472, steps per second: 156, episode reward:  7.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.536 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   24893/750000: episode: 40, duration: 2.731s, episode steps: 680, steps per second: 249, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.547 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
# Step 25000: saving model to checkpoints/dqn_v10_weights_25000.h5f
#   25933/750000: episode: 41, duration: 4.234s, episode steps: 1040, steps per second: 246, episode reward: 17.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.438 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   26609/750000: episode: 42, duration: 2.583s, episode steps: 676, steps per second: 262, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.522 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   27114/750000: episode: 43, duration: 2.628s, episode steps: 505, steps per second: 192, episode reward: 10.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.440 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   27789/750000: episode: 44, duration: 3.135s, episode steps: 675, steps per second: 215, episode reward:  5.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.425 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   28230/750000: episode: 45, duration: 1.668s, episode steps: 441, steps per second: 264, episode reward:  5.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.562 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   29012/750000: episode: 46, duration: 3.064s, episode steps: 782, steps per second: 255, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.560 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   29384/750000: episode: 47, duration: 1.434s, episode steps: 372, steps per second: 259, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.344 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   30095/750000: episode: 48, duration: 3.116s, episode steps: 711, steps per second: 228, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.460 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   30488/750000: episode: 49, duration: 2.331s, episode steps: 393, steps per second: 169, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.397 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   31307/750000: episode: 50, duration: 3.152s, episode steps: 819, steps per second: 260, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.510 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   32357/750000: episode: 51, duration: 3.995s, episode steps: 1050, steps per second: 263, episode reward: 13.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.420 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   32920/750000: episode: 52, duration: 2.161s, episode steps: 563, steps per second: 261, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.501 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   33757/750000: episode: 53, duration: 4.428s, episode steps: 837, steps per second: 189, episode reward: 15.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.351 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   34465/750000: episode: 54, duration: 2.702s, episode steps: 708, steps per second: 262, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.462 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   35207/750000: episode: 55, duration: 2.836s, episode steps: 742, steps per second: 262, episode reward:  5.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.457 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   36032/750000: episode: 56, duration: 3.132s, episode steps: 825, steps per second: 263, episode reward: 10.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.413 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   36579/750000: episode: 57, duration: 3.152s, episode steps: 547, steps per second: 174, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.406 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   37382/750000: episode: 58, duration: 3.269s, episode steps: 803, steps per second: 246, episode reward:  9.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.458 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   37781/750000: episode: 59, duration: 1.575s, episode steps: 399, steps per second: 253, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.459 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   38481/750000: episode: 60, duration: 2.742s, episode steps: 700, steps per second: 255, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.619 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   39147/750000: episode: 61, duration: 2.560s, episode steps: 666, steps per second: 260, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.584 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   40502/750000: episode: 62, duration: 6.428s, episode steps: 1355, steps per second: 211, episode reward: 24.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.477 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   41053/750000: episode: 63, duration: 2.127s, episode steps: 551, steps per second: 259, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.495 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   41685/750000: episode: 64, duration: 2.441s, episode steps: 632, steps per second: 259, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.451 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   42208/750000: episode: 65, duration: 2.024s, episode steps: 523, steps per second: 258, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.470 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   43098/750000: episode: 66, duration: 4.695s, episode steps: 890, steps per second: 190, episode reward: 15.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.509 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   44178/750000: episode: 67, duration: 4.097s, episode steps: 1080, steps per second: 264, episode reward: 19.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   44557/750000: episode: 68, duration: 1.449s, episode steps: 379, steps per second: 262, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.288 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   45115/750000: episode: 69, duration: 2.127s, episode steps: 558, steps per second: 262, episode reward:  5.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.502 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   45766/750000: episode: 70, duration: 3.230s, episode steps: 651, steps per second: 202, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.429 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   46241/750000: episode: 71, duration: 2.304s, episode steps: 475, steps per second: 206, episode reward:  7.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.419 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   46821/750000: episode: 72, duration: 2.200s, episode steps: 580, steps per second: 264, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.300 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   47265/750000: episode: 73, duration: 1.691s, episode steps: 444, steps per second: 263, episode reward:  4.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.291 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   48229/750000: episode: 74, duration: 3.659s, episode steps: 964, steps per second: 263, episode reward: 17.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   48977/750000: episode: 75, duration: 3.785s, episode steps: 748, steps per second: 198, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.544 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
#   49508/750000: episode: 76, duration: 2.364s, episode steps: 531, steps per second: 225, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.333 [0.000, 5.000],  loss: --, mean_q: --, mean_eps: --
# Step 50000: saving model to checkpoints/dqn_v10_weights_50000.h5f
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   50176/750000: episode: 77, duration: 5.889s, episode steps: 668, steps per second: 113, episode reward:  7.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.533 [0.000, 5.000],  loss: 0.005945, mean_q: 0.047132, mean_eps: 0.954919
#   50722/750000: episode: 78, duration: 12.187s, episode steps: 546, steps per second:  45, episode reward: 10.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.456 [0.000, 5.000],  loss: 0.006058, mean_q: 0.062423, mean_eps: 0.954595
#   51121/750000: episode: 79, duration: 9.125s, episode steps: 399, steps per second:  44, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.371 [0.000, 5.000],  loss: 0.006662, mean_q: 0.057909, mean_eps: 0.954167
#   51675/750000: episode: 80, duration: 12.188s, episode steps: 554, steps per second:  45, episode reward: 10.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.525 [0.000, 5.000],  loss: 0.008890, mean_q: 0.042399, mean_eps: 0.953740
#   52529/750000: episode: 81, duration: 17.788s, episode steps: 854, steps per second:  48, episode reward: 11.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.518 [0.000, 5.000],  loss: 0.004572, mean_q: 0.045651, mean_eps: 0.953110
#   52991/750000: episode: 82, duration: 10.468s, episode steps: 462, steps per second:  44, episode reward:  8.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.431 [0.000, 5.000],  loss: 0.007610, mean_q: 0.056218, mean_eps: 0.952516
#   53508/750000: episode: 83, duration: 11.096s, episode steps: 517, steps per second:  47, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: 0.008218, mean_q: 0.054419, mean_eps: 0.952075
#   54378/750000: episode: 84, duration: 17.958s, episode steps: 870, steps per second:  48, episode reward: 13.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.556 [0.000, 5.000],  loss: 0.005449, mean_q: 0.054842, mean_eps: 0.951454
#   55157/750000: episode: 85, duration: 16.220s, episode steps: 779, steps per second:  48, episode reward: 17.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.583 [0.000, 5.000],  loss: 0.007763, mean_q: 0.046963, mean_eps: 0.950711
#   55991/750000: episode: 86, duration: 19.084s, episode steps: 834, steps per second:  44, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.506 [0.000, 5.000],  loss: 0.006183, mean_q: 0.043450, mean_eps: 0.949982
#   57058/750000: episode: 87, duration: 21.935s, episode steps: 1067, steps per second:  49, episode reward: 18.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.548 [0.000, 5.000],  loss: 0.005864, mean_q: 0.022295, mean_eps: 0.949128
#   57621/750000: episode: 88, duration: 12.404s, episode steps: 563, steps per second:  45, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.586 [0.000, 5.000],  loss: 0.005859, mean_q: 0.045021, mean_eps: 0.948394
#   58034/750000: episode: 89, duration: 9.393s, episode steps: 413, steps per second:  44, episode reward:  5.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.504 [0.000, 5.000],  loss: 0.006641, mean_q: 0.033387, mean_eps: 0.947953
#   58644/750000: episode: 90, duration: 13.518s, episode steps: 610, steps per second:  45, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.433 [0.000, 5.000],  loss: 0.009889, mean_q: 0.044627, mean_eps: 0.947494
#   59149/750000: episode: 91, duration: 11.399s, episode steps: 505, steps per second:  44, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.450 [0.000, 5.000],  loss: 0.006286, mean_q: 0.046237, mean_eps: 0.946994
#   59873/750000: episode: 92, duration: 15.731s, episode steps: 724, steps per second:  46, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.454 [0.000, 5.000],  loss: 0.005910, mean_q: 0.043776, mean_eps: 0.946441
#   60494/750000: episode: 93, duration: 13.683s, episode steps: 621, steps per second:  45, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.581 [0.000, 5.000],  loss: 0.005798, mean_q: 0.063778, mean_eps: 0.945833
#   61672/750000: episode: 94, duration: 26.233s, episode steps: 1178, steps per second:  45, episode reward: 16.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.497 [0.000, 5.000],  loss: 0.008631, mean_q: 0.071084, mean_eps: 0.945024
#   62179/750000: episode: 95, duration: 11.208s, episode steps: 507, steps per second:  45, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.444 [0.000, 5.000],  loss: 0.006160, mean_q: 0.063937, mean_eps: 0.944268
#   62685/750000: episode: 96, duration: 11.500s, episode steps: 506, steps per second:  44, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.417 [0.000, 5.000],  loss: 0.008559, mean_q: 0.070509, mean_eps: 0.943813
#   63507/750000: episode: 97, duration: 17.624s, episode steps: 822, steps per second:  47, episode reward: 18.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 2.453 [0.000, 5.000],  loss: 0.007233, mean_q: 0.066286, mean_eps: 0.943215
#   64003/750000: episode: 98, duration: 11.059s, episode steps: 496, steps per second:  45, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.474 [0.000, 5.000],  loss: 0.008302, mean_q: 0.065496, mean_eps: 0.942620
#   64880/750000: episode: 99, duration: 18.408s, episode steps: 877, steps per second:  48, episode reward: 18.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.371 [0.000, 5.000],  loss: 0.007325, mean_q: 0.065928, mean_eps: 0.942004
#   65453/750000: episode: 100, duration: 12.255s, episode steps: 573, steps per second:  47, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.415 [0.000, 5.000],  loss: 0.005672, mean_q: 0.063690, mean_eps: 0.941351
#   65972/750000: episode: 101, duration: 11.247s, episode steps: 519, steps per second:  46, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.476 [0.000, 5.000],  loss: 0.005652, mean_q: 0.060380, mean_eps: 0.940856
#   66464/750000: episode: 102, duration: 10.834s, episode steps: 492, steps per second:  45, episode reward:  2.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 2.431 [0.000, 5.000],  loss: 0.007301, mean_q: 0.067785, mean_eps: 0.940402
#   67122/750000: episode: 103, duration: 14.066s, episode steps: 658, steps per second:  47, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.526 [0.000, 5.000],  loss: 0.005234, mean_q: 0.058566, mean_eps: 0.939884
#   67897/750000: episode: 104, duration: 16.166s, episode steps: 775, steps per second:  48, episode reward: 11.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.552 [0.000, 5.000],  loss: 0.006853, mean_q: 0.063569, mean_eps: 0.939241
#   68847/750000: episode: 105, duration: 20.926s, episode steps: 950, steps per second:  45, episode reward: 12.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.559 [0.000, 5.000],  loss: 0.006406, mean_q: 0.064526, mean_eps: 0.938467
#   69406/750000: episode: 106, duration: 12.154s, episode steps: 559, steps per second:  46, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.599 [0.000, 5.000],  loss: 0.005813, mean_q: 0.058348, mean_eps: 0.937787
#   70284/750000: episode: 107, duration: 18.436s, episode steps: 878, steps per second:  48, episode reward: 16.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.437 [0.000, 5.000],  loss: 0.007207, mean_q: 0.071541, mean_eps: 0.937140
#   70713/750000: episode: 108, duration: 9.686s, episode steps: 429, steps per second:  44, episode reward:  3.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.655 [0.000, 5.000],  loss: 0.007151, mean_q: 0.089284, mean_eps: 0.936550
#   71223/750000: episode: 109, duration: 11.333s, episode steps: 510, steps per second:  45, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.518 [0.000, 5.000],  loss: 0.008886, mean_q: 0.091802, mean_eps: 0.936127
#   71617/750000: episode: 110, duration: 7.455s, episode steps: 394, steps per second:  53, episode reward:  8.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.335 [0.000, 5.000],  loss: 0.007194, mean_q: 0.093185, mean_eps: 0.935722
#   72194/750000: episode: 111, duration: 12.479s, episode steps: 577, steps per second:  46, episode reward:  9.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.397 [0.000, 5.000],  loss: 0.005084, mean_q: 0.084377, mean_eps: 0.935286
#   72696/750000: episode: 112, duration: 11.139s, episode steps: 502, steps per second:  45, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.514 [0.000, 5.000],  loss: 0.003748, mean_q: 0.082027, mean_eps: 0.934800
#   73359/750000: episode: 113, duration: 14.038s, episode steps: 663, steps per second:  47, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.403 [0.000, 5.000],  loss: 0.007540, mean_q: 0.084787, mean_eps: 0.934278
#   73775/750000: episode: 114, duration: 9.445s, episode steps: 416, steps per second:  44, episode reward:  1.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 2.421 [0.000, 5.000],  loss: 0.008802, mean_q: 0.089704, mean_eps: 0.933791
#   74395/750000: episode: 115, duration: 13.305s, episode steps: 620, steps per second:  47, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.494 [0.000, 5.000],  loss: 0.008006, mean_q: 0.090725, mean_eps: 0.933323
# Step 75000: saving model to checkpoints/dqn_v10_weights_75000.h5f
#   75189/750000: episode: 116, duration: 16.872s, episode steps: 794, steps per second:  47, episode reward:  8.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.436 [0.000, 5.000],  loss: 0.005761, mean_q: 0.082222, mean_eps: 0.932689
#   75839/750000: episode: 117, duration: 13.993s, episode steps: 650, steps per second:  46, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.366 [0.000, 5.000],  loss: 0.008880, mean_q: 0.089617, mean_eps: 0.932041
#   76242/750000: episode: 118, duration: 9.338s, episode steps: 403, steps per second:  43, episode reward:  4.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: 0.005006, mean_q: 0.088788, mean_eps: 0.931564
#   76688/750000: episode: 119, duration: 9.874s, episode steps: 446, steps per second:  45, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.574 [0.000, 5.000],  loss: 0.007415, mean_q: 0.085593, mean_eps: 0.931181
#   77172/750000: episode: 120, duration: 9.434s, episode steps: 484, steps per second:  51, episode reward:  5.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.397 [0.000, 5.000],  loss: 0.004185, mean_q: 0.081924, mean_eps: 0.930763
#   77848/750000: episode: 121, duration: 15.083s, episode steps: 676, steps per second:  45, episode reward: 13.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.578 [0.000, 5.000],  loss: 0.007349, mean_q: 0.087973, mean_eps: 0.930241
#   78476/750000: episode: 122, duration: 13.911s, episode steps: 628, steps per second:  45, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.557 [0.000, 5.000],  loss: 0.006138, mean_q: 0.087028, mean_eps: 0.929656
#   78954/750000: episode: 123, duration: 9.537s, episode steps: 478, steps per second:  50, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.444 [0.000, 5.000],  loss: 0.008890, mean_q: 0.093570, mean_eps: 0.929157
#   79346/750000: episode: 124, duration: 8.942s, episode steps: 392, steps per second:  44, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.469 [0.000, 5.000],  loss: 0.005940, mean_q: 0.091809, mean_eps: 0.928765
#   80032/750000: episode: 125, duration: 14.587s, episode steps: 686, steps per second:  47, episode reward: 14.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.499 [0.000, 5.000],  loss: 0.006285, mean_q: 0.087851, mean_eps: 0.928279
#   81026/750000: episode: 126, duration: 21.981s, episode steps: 994, steps per second:  45, episode reward: 14.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.414 [0.000, 5.000],  loss: 0.007407, mean_q: 0.101442, mean_eps: 0.927523
#   81610/750000: episode: 127, duration: 12.783s, episode steps: 584, steps per second:  46, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.493 [0.000, 5.000],  loss: 0.007935, mean_q: 0.108521, mean_eps: 0.926816
#   82504/750000: episode: 128, duration: 18.710s, episode steps: 894, steps per second:  48, episode reward: 15.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.473 [0.000, 5.000],  loss: 0.006147, mean_q: 0.102814, mean_eps: 0.926150
#   83055/750000: episode: 129, duration: 11.950s, episode steps: 551, steps per second:  46, episode reward:  7.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.327 [0.000, 5.000],  loss: 0.006798, mean_q: 0.097996, mean_eps: 0.925498
#   84065/750000: episode: 130, duration: 22.255s, episode steps: 1010, steps per second:  45, episode reward: 20.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.618 [0.000, 5.000],  loss: 0.007827, mean_q: 0.102161, mean_eps: 0.924796
#   84572/750000: episode: 131, duration: 10.491s, episode steps: 507, steps per second:  48, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.477 [0.000, 5.000],  loss: 0.006095, mean_q: 0.100641, mean_eps: 0.924112
#   84938/750000: episode: 132, duration: 7.703s, episode steps: 366, steps per second:  48, episode reward:  4.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.637 [0.000, 5.000],  loss: 0.006102, mean_q: 0.090140, mean_eps: 0.923720
#   85838/750000: episode: 133, duration: 19.708s, episode steps: 900, steps per second:  46, episode reward: 15.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.538 [0.000, 5.000],  loss: 0.004906, mean_q: 0.093469, mean_eps: 0.923153
#   86693/750000: episode: 134, duration: 18.338s, episode steps: 855, steps per second:  47, episode reward: 10.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.374 [0.000, 5.000],  loss: 0.005779, mean_q: 0.093191, mean_eps: 0.922362
#   87087/750000: episode: 135, duration: 8.944s, episode steps: 394, steps per second:  44, episode reward:  7.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.756 [0.000, 5.000],  loss: 0.005622, mean_q: 0.095994, mean_eps: 0.921799
#   88028/750000: episode: 136, duration: 19.436s, episode steps: 941, steps per second:  48, episode reward: 18.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.560 [0.000, 5.000],  loss: 0.005645, mean_q: 0.096389, mean_eps: 0.921201
#   88543/750000: episode: 137, duration: 11.374s, episode steps: 515, steps per second:  45, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.412 [0.000, 5.000],  loss: 0.008340, mean_q: 0.101537, mean_eps: 0.920544
#   89208/750000: episode: 138, duration: 14.219s, episode steps: 665, steps per second:  47, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.594 [0.000, 5.000],  loss: 0.006783, mean_q: 0.093527, mean_eps: 0.920013
#   89812/750000: episode: 139, duration: 13.215s, episode steps: 604, steps per second:  46, episode reward:  8.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.548 [0.000, 5.000],  loss: 0.007296, mean_q: 0.101315, mean_eps: 0.919441
#   90354/750000: episode: 140, duration: 11.926s, episode steps: 542, steps per second:  45, episode reward:  8.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.771 [0.000, 5.000],  loss: 0.007557, mean_q: 0.106451, mean_eps: 0.918924
#   91077/750000: episode: 141, duration: 15.445s, episode steps: 723, steps per second:  47, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.732 [0.000, 5.000],  loss: 0.007091, mean_q: 0.108401, mean_eps: 0.918357
#   91885/750000: episode: 142, duration: 17.321s, episode steps: 808, steps per second:  47, episode reward:  8.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.339 [0.000, 5.000],  loss: 0.007642, mean_q: 0.104361, mean_eps: 0.917668
#   92582/750000: episode: 143, duration: 16.001s, episode steps: 697, steps per second:  44, episode reward:  5.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.409 [0.000, 5.000],  loss: 0.007065, mean_q: 0.099557, mean_eps: 0.916988
#   93211/750000: episode: 144, duration: 13.588s, episode steps: 629, steps per second:  46, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.434 [0.000, 5.000],  loss: 0.007152, mean_q: 0.102162, mean_eps: 0.916390
#   93772/750000: episode: 145, duration: 12.022s, episode steps: 561, steps per second:  47, episode reward:  7.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.602 [0.000, 5.000],  loss: 0.005912, mean_q: 0.107801, mean_eps: 0.915855
#   94438/750000: episode: 146, duration: 14.388s, episode steps: 666, steps per second:  46, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.447 [0.000, 5.000],  loss: 0.006949, mean_q: 0.098265, mean_eps: 0.915305
#   95192/750000: episode: 147, duration: 16.115s, episode steps: 754, steps per second:  47, episode reward: 13.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.654 [0.000, 5.000],  loss: 0.005912, mean_q: 0.102019, mean_eps: 0.914666
#   96073/750000: episode: 148, duration: 18.370s, episode steps: 881, steps per second:  48, episode reward:  9.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.516 [0.000, 5.000],  loss: 0.006407, mean_q: 0.097583, mean_eps: 0.913929
#   96561/750000: episode: 149, duration: 10.786s, episode steps: 488, steps per second:  45, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.553 [0.000, 5.000],  loss: 0.006921, mean_q: 0.103702, mean_eps: 0.913312
#   97256/750000: episode: 150, duration: 14.868s, episode steps: 695, steps per second:  47, episode reward:  9.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.649 [0.000, 5.000],  loss: 0.008244, mean_q: 0.110600, mean_eps: 0.912781
#   98050/750000: episode: 151, duration: 18.025s, episode steps: 794, steps per second:  44, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.480 [0.000, 5.000],  loss: 0.006129, mean_q: 0.098172, mean_eps: 0.912115
#   98588/750000: episode: 152, duration: 10.787s, episode steps: 538, steps per second:  50, episode reward:  4.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 2.586 [0.000, 5.000],  loss: 0.005796, mean_q: 0.106068, mean_eps: 0.911516
#   99095/750000: episode: 153, duration: 11.103s, episode steps: 507, steps per second:  46, episode reward:  8.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.396 [0.000, 5.000],  loss: 0.004925, mean_q: 0.090774, mean_eps: 0.911044
# Step 100000: saving model to checkpoints/dqn_v10_weights_100000.h5f
#  100243/750000: episode: 154, duration: 24.931s, episode steps: 1148, steps per second:  46, episode reward: 14.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.412 [0.000, 5.000],  loss: 0.006739, mean_q: 0.102067, mean_eps: 0.910297
#  101251/750000: episode: 155, duration: 22.612s, episode steps: 1008, steps per second:  45, episode reward: 13.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.390 [0.000, 5.000],  loss: 0.005598, mean_q: 0.107590, mean_eps: 0.909325
#  101878/750000: episode: 156, duration: 13.846s, episode steps: 627, steps per second:  45, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.407 [0.000, 5.000],  loss: 0.006540, mean_q: 0.107150, mean_eps: 0.908591
#  102387/750000: episode: 157, duration: 11.583s, episode steps: 509, steps per second:  44, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.511 [0.000, 5.000],  loss: 0.003443, mean_q: 0.103781, mean_eps: 0.908083
#  103009/750000: episode: 158, duration: 13.889s, episode steps: 622, steps per second:  45, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.632 [0.000, 5.000],  loss: 0.006284, mean_q: 0.104454, mean_eps: 0.907574
#  103667/750000: episode: 159, duration: 14.339s, episode steps: 658, steps per second:  46, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.549 [0.000, 5.000],  loss: 0.004470, mean_q: 0.110339, mean_eps: 0.906999
#  104361/750000: episode: 160, duration: 15.270s, episode steps: 694, steps per second:  45, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.329 [0.000, 5.000],  loss: 0.006065, mean_q: 0.107933, mean_eps: 0.906386
#  104975/750000: episode: 161, duration: 13.529s, episode steps: 614, steps per second:  45, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.381 [0.000, 5.000],  loss: 0.006852, mean_q: 0.109229, mean_eps: 0.905797
#  105769/750000: episode: 162, duration: 17.514s, episode steps: 794, steps per second:  45, episode reward: 11.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.626 [0.000, 5.000],  loss: 0.006078, mean_q: 0.105060, mean_eps: 0.905167
#  107054/750000: episode: 163, duration: 29.352s, episode steps: 1285, steps per second:  44, episode reward: 27.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.623 [0.000, 5.000],  loss: 0.006051, mean_q: 0.104823, mean_eps: 0.904231
#  107820/750000: episode: 164, duration: 16.361s, episode steps: 766, steps per second:  47, episode reward: 14.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.457 [0.000, 5.000],  loss: 0.008010, mean_q: 0.111982, mean_eps: 0.903308
#  108455/750000: episode: 165, duration: 13.966s, episode steps: 635, steps per second:  45, episode reward: 11.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.409 [0.000, 5.000],  loss: 0.005422, mean_q: 0.105850, mean_eps: 0.902678
#  108947/750000: episode: 166, duration: 11.048s, episode steps: 492, steps per second:  45, episode reward:  6.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.661 [0.000, 5.000],  loss: 0.007260, mean_q: 0.104556, mean_eps: 0.902170
#  109625/750000: episode: 167, duration: 14.885s, episode steps: 678, steps per second:  46, episode reward:  6.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.426 [0.000, 5.000],  loss: 0.006793, mean_q: 0.114659, mean_eps: 0.901643
#  110476/750000: episode: 168, duration: 18.475s, episode steps: 851, steps per second:  46, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.340 [0.000, 5.000],  loss: 0.007263, mean_q: 0.144705, mean_eps: 0.900955
#  111107/750000: episode: 169, duration: 14.062s, episode steps: 631, steps per second:  45, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.428 [0.000, 5.000],  loss: 0.006719, mean_q: 0.159529, mean_eps: 0.900289
#  111777/750000: episode: 170, duration: 16.018s, episode steps: 670, steps per second:  42, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.403 [0.000, 5.000],  loss: 0.005618, mean_q: 0.162071, mean_eps: 0.899704
#  112660/750000: episode: 171, duration: 19.841s, episode steps: 883, steps per second:  45, episode reward:  9.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.523 [0.000, 5.000],  loss: 0.005466, mean_q: 0.157600, mean_eps: 0.899007
#  113679/750000: episode: 172, duration: 23.296s, episode steps: 1019, steps per second:  44, episode reward: 18.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.459 [0.000, 5.000],  loss: 0.005564, mean_q: 0.156380, mean_eps: 0.898151
#  114099/750000: episode: 173, duration: 9.100s, episode steps: 420, steps per second:  46, episode reward:  6.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.605 [0.000, 5.000],  loss: 0.008216, mean_q: 0.152415, mean_eps: 0.897504
#  114655/750000: episode: 174, duration: 11.914s, episode steps: 556, steps per second:  47, episode reward: 10.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.513 [0.000, 5.000],  loss: 0.006348, mean_q: 0.155323, mean_eps: 0.897062
#  115240/750000: episode: 175, duration: 13.150s, episode steps: 585, steps per second:  44, episode reward:  6.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.564 [0.000, 5.000],  loss: 0.005734, mean_q: 0.154809, mean_eps: 0.896549
#  115963/750000: episode: 176, duration: 17.193s, episode steps: 723, steps per second:  42, episode reward:  8.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.484 [0.000, 5.000],  loss: 0.006219, mean_q: 0.161275, mean_eps: 0.895960
#  116889/750000: episode: 177, duration: 19.515s, episode steps: 926, steps per second:  47, episode reward: 10.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.356 [0.000, 5.000],  loss: 0.006921, mean_q: 0.163171, mean_eps: 0.895217
#  117624/750000: episode: 178, duration: 15.976s, episode steps: 735, steps per second:  46, episode reward:  9.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.356 [0.000, 5.000],  loss: 0.007000, mean_q: 0.161606, mean_eps: 0.894470
#  118339/750000: episode: 179, duration: 16.512s, episode steps: 715, steps per second:  43, episode reward: 11.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.389 [0.000, 5.000],  loss: 0.006936, mean_q: 0.156712, mean_eps: 0.893818
#  119023/750000: episode: 180, duration: 15.150s, episode steps: 684, steps per second:  45, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.661 [0.000, 5.000],  loss: 0.007004, mean_q: 0.152220, mean_eps: 0.893188
#  119629/750000: episode: 181, duration: 13.326s, episode steps: 606, steps per second:  45, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.597 [0.000, 5.000],  loss: 0.004314, mean_q: 0.151255, mean_eps: 0.892607
#  120299/750000: episode: 182, duration: 14.518s, episode steps: 670, steps per second:  46, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.510 [0.000, 5.000],  loss: 0.005858, mean_q: 0.159321, mean_eps: 0.892036
#  120769/750000: episode: 183, duration: 10.598s, episode steps: 470, steps per second:  44, episode reward:  6.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.389 [0.000, 5.000],  loss: 0.007274, mean_q: 0.180928, mean_eps: 0.891523
#  121558/750000: episode: 184, duration: 16.778s, episode steps: 789, steps per second:  47, episode reward: 10.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.278 [0.000, 5.000],  loss: 0.008343, mean_q: 0.186333, mean_eps: 0.890956
#  121956/750000: episode: 185, duration: 9.298s, episode steps: 398, steps per second:  43, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.565 [0.000, 5.000],  loss: 0.006315, mean_q: 0.180183, mean_eps: 0.890421
#  122840/750000: episode: 186, duration: 18.769s, episode steps: 884, steps per second:  47, episode reward: 16.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.479 [0.000, 5.000],  loss: 0.007013, mean_q: 0.179917, mean_eps: 0.889845
#  123435/750000: episode: 187, duration: 13.078s, episode steps: 595, steps per second:  45, episode reward:  5.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.607 [0.000, 5.000],  loss: 0.007269, mean_q: 0.179099, mean_eps: 0.889178
#  124119/750000: episode: 188, duration: 14.710s, episode steps: 684, steps per second:  46, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.497 [0.000, 5.000],  loss: 0.007078, mean_q: 0.180035, mean_eps: 0.888602
# Step 125000: saving model to checkpoints/dqn_v10_weights_125000.h5f
#  125759/750000: episode: 189, duration: 36.313s, episode steps: 1640, steps per second:  45, episode reward: 19.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.522 [0.000, 5.000],  loss: 0.006021, mean_q: 0.181227, mean_eps: 0.887559
#  126292/750000: episode: 190, duration: 11.988s, episode steps: 533, steps per second:  44, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.482 [0.000, 5.000],  loss: 0.007173, mean_q: 0.180777, mean_eps: 0.886578
#  126847/750000: episode: 191, duration: 12.322s, episode steps: 555, steps per second:  45, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.638 [0.000, 5.000],  loss: 0.007095, mean_q: 0.182758, mean_eps: 0.886087
#  127495/750000: episode: 192, duration: 14.258s, episode steps: 648, steps per second:  45, episode reward:  8.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.418 [0.000, 5.000],  loss: 0.005311, mean_q: 0.173497, mean_eps: 0.885547
#  128353/750000: episode: 193, duration: 18.344s, episode steps: 858, steps per second:  47, episode reward: 12.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.485 [0.000, 5.000],  loss: 0.006857, mean_q: 0.178890, mean_eps: 0.884868
#  128998/750000: episode: 194, duration: 14.009s, episode steps: 645, steps per second:  46, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.338 [0.000, 5.000],  loss: 0.006117, mean_q: 0.181196, mean_eps: 0.884193
#  129590/750000: episode: 195, duration: 13.195s, episode steps: 592, steps per second:  45, episode reward:  8.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.270 [0.000, 5.000],  loss: 0.007131, mean_q: 0.178166, mean_eps: 0.883639
#  130141/750000: episode: 196, duration: 12.409s, episode steps: 551, steps per second:  44, episode reward:  6.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.367 [0.000, 5.000],  loss: 0.007423, mean_q: 0.187626, mean_eps: 0.883121
#  131613/750000: episode: 197, duration: 33.304s, episode steps: 1472, steps per second:  44, episode reward: 19.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.440 [0.000, 5.000],  loss: 0.006467, mean_q: 0.209321, mean_eps: 0.882208
#  132024/750000: episode: 198, duration: 8.035s, episode steps: 411, steps per second:  51, episode reward:  6.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.328 [0.000, 5.000],  loss: 0.007657, mean_q: 0.210643, mean_eps: 0.881362
#  132648/750000: episode: 199, duration: 13.718s, episode steps: 624, steps per second:  45, episode reward:  9.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.244 [0.000, 5.000],  loss: 0.006721, mean_q: 0.212358, mean_eps: 0.880899
#  133148/750000: episode: 200, duration: 11.393s, episode steps: 500, steps per second:  44, episode reward:  4.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 2.482 [0.000, 5.000],  loss: 0.006678, mean_q: 0.202478, mean_eps: 0.880394
# ...
#  705321/750000: episode: 999, duration: 26.733s, episode steps: 985, steps per second:  37, episode reward: 18.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.778 [0.000, 5.000],  loss: 0.007793, mean_q: 0.928797, mean_eps: 0.365653
#  705933/750000: episode: 1000, duration: 16.293s, episode steps: 612, steps per second:  38, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.217 [0.000, 5.000],  loss: 0.008973, mean_q: 0.949869, mean_eps: 0.364933
#  706431/750000: episode: 1001, duration: 13.586s, episode steps: 498, steps per second:  37, episode reward: 14.000, mean reward:  0.028 [ 0.000,  1.000], mean action: 3.187 [0.000, 5.000],  loss: 0.007654, mean_q: 0.936993, mean_eps: 0.364434
#  706765/750000: episode: 1002, duration: 9.344s, episode steps: 334, steps per second:  36, episode reward:  4.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 3.952 [0.000, 5.000],  loss: 0.010040, mean_q: 0.925637, mean_eps: 0.364060
#  707535/750000: episode: 1003, duration: 20.324s, episode steps: 770, steps per second:  38, episode reward: 12.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 1.942 [0.000, 5.000],  loss: 0.011096, mean_q: 0.965666, mean_eps: 0.363565
#  708248/750000: episode: 1004, duration: 19.953s, episode steps: 713, steps per second:  36, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 3.087 [0.000, 5.000],  loss: 0.009863, mean_q: 0.932974, mean_eps: 0.362899
#  708822/750000: episode: 1005, duration: 15.551s, episode steps: 574, steps per second:  37, episode reward: 10.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.195 [0.000, 5.000],  loss: 0.009727, mean_q: 0.940057, mean_eps: 0.362318
#  710076/750000: episode: 1006, duration: 34.675s, episode steps: 1254, steps per second:  36, episode reward: 18.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.200 [0.000, 5.000],  loss: 0.011200, mean_q: 0.944244, mean_eps: 0.361495
#  710766/750000: episode: 1007, duration: 18.359s, episode steps: 690, steps per second:  38, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.299 [0.000, 5.000],  loss: 0.008027, mean_q: 0.964040, mean_eps: 0.360622
#  711134/750000: episode: 1008, duration: 10.406s, episode steps: 368, steps per second:  35, episode reward:  5.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.149 [0.000, 5.000],  loss: 0.007472, mean_q: 0.979334, mean_eps: 0.360145
#  712157/750000: episode: 1009, duration: 27.773s, episode steps: 1023, steps per second:  37, episode reward: 12.000, mean reward:  0.012 [ 0.000,  1.000], mean action: 2.419 [0.000, 5.000],  loss: 0.008681, mean_q: 0.962014, mean_eps: 0.359519
#  712647/750000: episode: 1010, duration: 13.376s, episode steps: 490, steps per second:  37, episode reward:  7.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.690 [0.000, 5.000],  loss: 0.007478, mean_q: 0.976540, mean_eps: 0.358840
#  713337/750000: episode: 1011, duration: 19.665s, episode steps: 690, steps per second:  35, episode reward: 10.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 1.991 [0.000, 5.000],  loss: 0.008927, mean_q: 0.973354, mean_eps: 0.358309
#  714048/750000: episode: 1012, duration: 19.031s, episode steps: 711, steps per second:  37, episode reward: 14.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.211 [0.000, 5.000],  loss: 0.009142, mean_q: 0.953930, mean_eps: 0.357679
#  715048/750000: episode: 1013, duration: 27.491s, episode steps: 1000, steps per second:  36, episode reward: 25.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 1.864 [0.000, 5.000],  loss: 0.009160, mean_q: 0.976358, mean_eps: 0.356909
#  715396/750000: episode: 1014, duration: 9.807s, episode steps: 348, steps per second:  35, episode reward:  4.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 3.325 [0.000, 5.000],  loss: 0.007769, mean_q: 0.968754, mean_eps: 0.356302
#  715863/750000: episode: 1015, duration: 12.931s, episode steps: 467, steps per second:  36, episode reward:  7.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 3.343 [0.000, 5.000],  loss: 0.008932, mean_q: 0.948837, mean_eps: 0.355933
#  716257/750000: episode: 1016, duration: 11.024s, episode steps: 394, steps per second:  36, episode reward:  5.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.624 [0.000, 5.000],  loss: 0.009011, mean_q: 0.966548, mean_eps: 0.355546
#  716645/750000: episode: 1017, duration: 10.947s, episode steps: 388, steps per second:  35, episode reward:  8.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.874 [0.000, 5.000],  loss: 0.008149, mean_q: 0.936763, mean_eps: 0.355195
#  716998/750000: episode: 1018, duration: 8.829s, episode steps: 353, steps per second:  40, episode reward:  5.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 1.530 [0.000, 5.000],  loss: 0.010995, mean_q: 0.939012, mean_eps: 0.354862
#  717511/750000: episode: 1019, duration: 14.599s, episode steps: 513, steps per second:  35, episode reward: 10.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.246 [0.000, 5.000],  loss: 0.009066, mean_q: 0.942689, mean_eps: 0.354470
#  718323/750000: episode: 1020, duration: 22.319s, episode steps: 812, steps per second:  36, episode reward: 14.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 1.872 [0.000, 5.000],  loss: 0.007617, mean_q: 0.960987, mean_eps: 0.353872
#  719027/750000: episode: 1021, duration: 19.781s, episode steps: 704, steps per second:  36, episode reward: 16.000, mean reward:  0.023 [ 0.000,  1.000], mean action: 1.561 [0.000, 5.000],  loss: 0.011104, mean_q: 0.972383, mean_eps: 0.353192
#  719924/750000: episode: 1022, duration: 24.854s, episode steps: 897, steps per second:  36, episode reward: 12.000, mean reward:  0.013 [ 0.000,  1.000], mean action: 2.312 [0.000, 5.000],  loss: 0.008966, mean_q: 0.957910, mean_eps: 0.352472
#  720397/750000: episode: 1023, duration: 12.936s, episode steps: 473, steps per second:  37, episode reward:  5.000, mean reward:  0.011 [ 0.000,  1.000], mean action: 2.615 [0.000, 5.000],  loss: 0.009085, mean_q: 0.986828, mean_eps: 0.351856
#  720917/750000: episode: 1024, duration: 14.432s, episode steps: 520, steps per second:  36, episode reward:  9.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.304 [0.000, 5.000],  loss: 0.011761, mean_q: 0.972935, mean_eps: 0.351410
#  721502/750000: episode: 1025, duration: 15.939s, episode steps: 585, steps per second:  37, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.224 [0.000, 5.000],  loss: 0.009327, mean_q: 0.961521, mean_eps: 0.350911
#  721968/750000: episode: 1026, duration: 12.819s, episode steps: 466, steps per second:  36, episode reward:  7.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.487 [0.000, 5.000],  loss: 0.007993, mean_q: 0.954080, mean_eps: 0.350438
#  722585/750000: episode: 1027, duration: 16.641s, episode steps: 617, steps per second:  37, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.284 [0.000, 5.000],  loss: 0.007942, mean_q: 0.963833, mean_eps: 0.349952
#  722898/750000: episode: 1028, duration: 8.964s, episode steps: 313, steps per second:  35, episode reward:  3.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.329 [0.000, 5.000],  loss: 0.008775, mean_q: 0.939492, mean_eps: 0.349534
#  723796/750000: episode: 1029, duration: 25.008s, episode steps: 898, steps per second:  36, episode reward: 13.000, mean reward:  0.014 [ 0.000,  1.000], mean action: 2.606 [0.000, 5.000],  loss: 0.008918, mean_q: 0.972070, mean_eps: 0.348989
#  724693/750000: episode: 1030, duration: 25.156s, episode steps: 897, steps per second:  36, episode reward: 15.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.717 [0.000, 5.000],  loss: 0.009664, mean_q: 0.955743, mean_eps: 0.348179
# Step 725000: saving model to checkpoints/dqn_v10_weights_725000.h5f
#  725382/750000: episode: 1031, duration: 18.579s, episode steps: 689, steps per second:  37, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.003 [0.000, 5.000],  loss: 0.009766, mean_q: 0.945620, mean_eps: 0.347464
#  725703/750000: episode: 1032, duration: 9.234s, episode steps: 321, steps per second:  35, episode reward:  3.000, mean reward:  0.009 [ 0.000,  1.000], mean action: 2.265 [0.000, 5.000],  loss: 0.006481, mean_q: 0.958135, mean_eps: 0.347009
#  726389/750000: episode: 1033, duration: 18.246s, episode steps: 686, steps per second:  38, episode reward: 11.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.813 [0.000, 5.000],  loss: 0.007400, mean_q: 0.953523, mean_eps: 0.346559
#  726881/750000: episode: 1034, duration: 13.758s, episode steps: 492, steps per second:  36, episode reward: 10.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.768 [0.000, 5.000],  loss: 0.009819, mean_q: 0.952602, mean_eps: 0.346028
#  727330/750000: episode: 1035, duration: 12.493s, episode steps: 449, steps per second:  36, episode reward:  7.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.924 [0.000, 5.000],  loss: 0.010139, mean_q: 0.950266, mean_eps: 0.345605
#  728502/750000: episode: 1036, duration: 33.133s, episode steps: 1172, steps per second:  35, episode reward: 17.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.183 [0.000, 5.000],  loss: 0.010416, mean_q: 0.956130, mean_eps: 0.344876
#  729543/750000: episode: 1037, duration: 28.709s, episode steps: 1041, steps per second:  36, episode reward: 19.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.301 [0.000, 5.000],  loss: 0.008641, mean_q: 0.948950, mean_eps: 0.343877
#  730597/750000: episode: 1038, duration: 28.853s, episode steps: 1054, steps per second:  37, episode reward: 20.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 1.884 [0.000, 5.000],  loss: 0.009932, mean_q: 0.986969, mean_eps: 0.342937
#  732123/750000: episode: 1039, duration: 43.151s, episode steps: 1526, steps per second:  35, episode reward: 15.000, mean reward:  0.010 [ 0.000,  1.000], mean action: 2.282 [0.000, 5.000],  loss: 0.010203, mean_q: 0.976053, mean_eps: 0.341776
#  732754/750000: episode: 1040, duration: 17.369s, episode steps: 631, steps per second:  36, episode reward: 12.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 2.276 [0.000, 5.000],  loss: 0.009675, mean_q: 0.974135, mean_eps: 0.340804
#  733446/750000: episode: 1041, duration: 18.626s, episode steps: 692, steps per second:  37, episode reward: 17.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 2.311 [0.000, 5.000],  loss: 0.009392, mean_q: 0.983695, mean_eps: 0.340210
#  734447/750000: episode: 1042, duration: 27.805s, episode steps: 1001, steps per second:  36, episode reward: 27.000, mean reward:  0.027 [ 0.000,  1.000], mean action: 2.332 [0.000, 5.000],  loss: 0.008433, mean_q: 0.964848, mean_eps: 0.339449
#  735614/750000: episode: 1043, duration: 32.680s, episode steps: 1167, steps per second:  36, episode reward: 29.000, mean reward:  0.025 [ 0.000,  1.000], mean action: 2.408 [0.000, 5.000],  loss: 0.008142, mean_q: 0.960873, mean_eps: 0.338473
#  736751/750000: episode: 1044, duration: 31.290s, episode steps: 1137, steps per second:  36, episode reward: 21.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.364 [0.000, 5.000],  loss: 0.009631, mean_q: 0.969613, mean_eps: 0.337433
#  737391/750000: episode: 1045, duration: 18.480s, episode steps: 640, steps per second:  35, episode reward: 13.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.514 [0.000, 5.000],  loss: 0.009211, mean_q: 0.964614, mean_eps: 0.336633
#  738202/750000: episode: 1046, duration: 22.489s, episode steps: 811, steps per second:  36, episode reward: 12.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.253 [0.000, 5.000],  loss: 0.009946, mean_q: 0.972953, mean_eps: 0.335980
#  739314/750000: episode: 1047, duration: 31.341s, episode steps: 1112, steps per second:  35, episode reward: 17.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.066 [0.000, 5.000],  loss: 0.009341, mean_q: 0.961093, mean_eps: 0.335116
#  739953/750000: episode: 1048, duration: 17.489s, episode steps: 639, steps per second:  37, episode reward: 10.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.330 [0.000, 5.000],  loss: 0.007580, mean_q: 0.946694, mean_eps: 0.334328
#  740596/750000: episode: 1049, duration: 18.859s, episode steps: 643, steps per second:  34, episode reward: 14.000, mean reward:  0.022 [ 0.000,  1.000], mean action: 3.204 [0.000, 5.000],  loss: 0.009782, mean_q: 0.960907, mean_eps: 0.333752
#  741274/750000: episode: 1050, duration: 19.021s, episode steps: 678, steps per second:  36, episode reward: 10.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.717 [0.000, 5.000],  loss: 0.009228, mean_q: 0.976309, mean_eps: 0.333159
#  741633/750000: episode: 1051, duration: 10.344s, episode steps: 359, steps per second:  35, episode reward:  6.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 2.212 [0.000, 5.000],  loss: 0.006892, mean_q: 1.020099, mean_eps: 0.332691
#  742332/750000: episode: 1052, duration: 18.958s, episode steps: 699, steps per second:  37, episode reward: 12.000, mean reward:  0.017 [ 0.000,  1.000], mean action: 3.013 [0.000, 5.000],  loss: 0.012369, mean_q: 0.996708, mean_eps: 0.332213
#  743124/750000: episode: 1053, duration: 22.673s, episode steps: 792, steps per second:  35, episode reward: 21.000, mean reward:  0.027 [ 0.000,  1.000], mean action: 2.394 [0.000, 5.000],  loss: 0.008195, mean_q: 0.986243, mean_eps: 0.331543
#  743592/750000: episode: 1054, duration: 13.460s, episode steps: 468, steps per second:  35, episode reward: 11.000, mean reward:  0.024 [ 0.000,  1.000], mean action: 2.391 [0.000, 5.000],  loss: 0.007537, mean_q: 0.964051, mean_eps: 0.330976
#  744548/750000: episode: 1055, duration: 27.082s, episode steps: 956, steps per second:  35, episode reward: 18.000, mean reward:  0.019 [ 0.000,  1.000], mean action: 1.817 [0.000, 5.000],  loss: 0.010270, mean_q: 0.986819, mean_eps: 0.330337
#  745402/750000: episode: 1056, duration: 24.363s, episode steps: 854, steps per second:  35, episode reward: 17.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.180 [0.000, 5.000],  loss: 0.008983, mean_q: 0.995380, mean_eps: 0.329522
#  746137/750000: episode: 1057, duration: 20.985s, episode steps: 735, steps per second:  35, episode reward: 13.000, mean reward:  0.018 [ 0.000,  1.000], mean action: 2.120 [0.000, 5.000],  loss: 0.011894, mean_q: 0.997939, mean_eps: 0.328807
#  746666/750000: episode: 1058, duration: 14.811s, episode steps: 529, steps per second:  36, episode reward: 11.000, mean reward:  0.021 [ 0.000,  1.000], mean action: 2.565 [0.000, 5.000],  loss: 0.010293, mean_q: 0.988806, mean_eps: 0.328240
#  747249/750000: episode: 1059, duration: 15.835s, episode steps: 583, steps per second:  37, episode reward:  9.000, mean reward:  0.015 [ 0.000,  1.000], mean action: 2.652 [0.000, 5.000],  loss: 0.007976, mean_q: 0.960364, mean_eps: 0.327740
#  748143/750000: episode: 1060, duration: 25.385s, episode steps: 894, steps per second:  35, episode reward: 23.000, mean reward:  0.026 [ 0.000,  1.000], mean action: 2.744 [0.000, 5.000],  loss: 0.007758, mean_q: 0.979911, mean_eps: 0.327074
#  749241/750000: episode: 1061, duration: 30.156s, episode steps: 1098, steps per second:  36, episode reward: 18.000, mean reward:  0.016 [ 0.000,  1.000], mean action: 2.462 [0.000, 5.000],  loss: 0.009669, mean_q: 0.975867, mean_eps: 0.326174
#  749741/750000: episode: 1062, duration: 14.204s, episode steps: 500, steps per second:  35, episode reward: 10.000, mean reward:  0.020 [ 0.000,  1.000], mean action: 2.158 [0.000, 5.000],  loss: 0.007456, mean_q: 0.973467, mean_eps: 0.325454
# Step 750000: saving model to checkpoints/dqn_v10_weights_750000.h5f
# done, took 17348.685 seconds
# ⏱ Tiempo de fin: 19:14:09

# %%
# Testing part to calculate the mean reward a los 500k
#weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
weights_filename = 'dqn_v10_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 11.000, steps: 684
# Episode 2: reward: 7.000, steps: 512
# Episode 3: reward: 13.000, steps: 882
# Episode 4: reward: 14.000, steps: 853
# Episode 5: reward: 14.000, steps: 850
# Episode 6: reward: 8.000, steps: 658
# Episode 7: reward: 16.000, steps: 859
# Episode 8: reward: 12.000, steps: 826
# Episode 9: reward: 12.000, steps: 734
# Episode 10: reward: 12.000, steps: 710

# %%
from google.colab import drive
import shutil
import glob  # <-- ¡Falta este import!
import os

# 1. Montar Google Drive
#drive.mount('/content/drive')

# 2. Crear directorio en Drive si no existe
os.makedirs('/content/gdrive/MyDrive/Colab_Outputs', exist_ok=True)

# 3. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('dqn_v10_weights*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )
    print(f"¡Archivo {archivo} copiado a Drive!")

# 4. Buscar y copiar todos los archivos coincidentes
archivos = glob.glob('checkpoints/dqn_v10_weights_750000*')  # Encuentra todos los archivos con ese patrón

for archivo in archivos:
    shutil.copy(
        archivo,
        f'/content/gdrive/MyDrive/Colab_Outputs/{os.path.basename(archivo)}'
    )

print("✅ ¡Todos los archivos copiados!")
# Out:
# ¡Archivo dqn_v10_weights.h5f.data-00000-of-00001 copiado a Drive!
# ¡Archivo dqn_v10_weights.h5f.index copiado a Drive!
# ✅ ¡Todos los archivos copiados!
